# %% [markdown]
# # Task 4.8

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Changing view format

pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# ### Import the orders_products_merged dataframe from the pickle file saved

# %%
path = r'C:\Users\IVON6\Instacart Basket Analysis'

# %%
# Import dataset orders_products_merged.pkl
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged_new_columns.pkl'))

# %%
# Check dimensions of imported dataframe for consistency
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %% [markdown]
# ## Find the aggregated mean of the “order_number” column grouped by “department_id

# %%
# Split the data into groups based on 'department_id'
# Apply the agg() function to each group to obtain the mean values for the 'order_number' column
ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1    15.46
# 2    17.28
# 3    17.17
# 4    17.81
# 5    15.22
# 6    16.44
# 7    17.23
# 8    15.34
# 9    15.90
# 10   20.20
# 11   16.17
# 12   15.89
# 13   16.58
# 14   16.77
# 15   16.17
# 16   17.67
# 17   15.69
# 18   19.31
# 19   17.18
# 20   16.47
# 21   22.90
# Name: order_number, dtype: float64

# %%
#In my subset, the number of departments are the same.
#The differences between the average values for the number of orders are evident.They have changed.

# %% [markdown]
# ## Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
# Split the data into groups based on the “user_id” column
# Apply the transform() function on the “order_number” column to generate the maximum orders for each user
# Create a new column, “max_order”

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
ords_prods_merge['max_order']
# Out:
# C:\Users\IVON6\AppData\Local\Temp\ipykernel_24192\3220249672.py:5: FutureWarning: The provided callable <function max at 0x0000022E7B6E9F80> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# 0           32
# 1           32
# 2            5
# 3            3
# 4            3
#             ..
# 32404854     6
# 32404855     4
# 32404856    20
# 32404857    20
# 32404858    11
# Name: max_order, Length: 32404859, dtype: int64

# %%
# testing the output

ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19    5.80
# 1            1  Chocolate Sandwich Cookies        61             19    5.80
# 2            1  Chocolate Sandwich Cookies        61             19    5.80
# 3            1  Chocolate Sandwich Cookies        61             19    5.80
# 4            1  Chocolate Sandwich Cookies        61             19    5.80
# 5            1  Chocolate Sandwich Cookies        61             19    5.80
# 6            1  Chocolate Sandwich Cookies        61             19    5.80
# 7            1  Chocolate Sandwich Cookies        61             19    5.80
# 8            1  Chocolate Sandwich Cookies        61             19    5.80
# 9            1  Chocolate Sandwich Cookies        61             19    5.80
# 10           1  Chocolate Sandwich Cookies        61             19    5.80
# ...

# %%
# Removing output limit from 100 to none

pd.options.display.max_rows = None

# %% [markdown]
# ## Deriving Columns with loc()

# %%
# max orders > 40 --> Loyal customer

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
# max orders > 10 and <= 40 --> Regular customer

ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
# max orders < 10 --> New customer

ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Checking the results

ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Check new column 

ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(20)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6

# %%
# Check the whole dataframe

ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19    5.80
# 1           1  Chocolate Sandwich Cookies        61             19    5.80
# 2           1  Chocolate Sandwich Cookies        61             19    5.80
# 3           1  Chocolate Sandwich Cookies        61             19    5.80
# 4           1  Chocolate Sandwich Cookies        61             19    5.80
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
# ...

# %% [markdown]
# ## Look at Spending Habits of Loyalty Groups

# %%
# Checking the spending habits between the three types of customers in terms of product price

customer_differ = ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max', 'sum']})
customer_differ
# Out:
#                  prices
#                    mean  min      max          sum
# loyalty_flag
# Loyal customer    10.39 1.00 99999.00 106814042.20
# New customer      13.29 1.00 99999.00  83011787.20
# Regular customer  12.50 1.00 99999.00 198391693.20

# %%
# During a comparative analysis of customer groups based on their loyalty, I was found that new customers have the highest average purchase cost.

# %% [markdown]
# ## Create a spending flag for each user based on the average price across all their orders using the following criteria:

# %%
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# First Step: Group by user_id, calculate the average value by price and create a new column 'mean_price'

ords_prods_merge['mean_price'] = ords_prods_merge.groupby('user_id')['prices'].transform('mean')

# %%
ords_prods_merge['mean_price'].describe()
# Out:
# count   32404859.00
# mean          11.98
# std           83.24
# min            1.00
# 25%            7.39
# 50%            7.82
# 75%            8.25
# max        25005.42
# Name: mean_price, dtype: float64

# %%
# Second Step: Creating Flags

# %%
# mean_price by user is < 10 --> Low spender
ords_prods_merge.loc[ords_prods_merge['mean_price'] < 10, 'spenders'] = 'Low spender'

# %%
# mean_price by user is >= 10 --> High spender
ords_prods_merge.loc[ords_prods_merge['mean_price'] >= 10, 'spenders'] = 'High spender'

# %%
# checking output
ords_prods_merge[['user_id', 'mean_price', 'spenders']].head(30)
# Out:
#     user_id  mean_price     spenders
# 0       138        6.94  Low spender
# 1       138        6.94  Low spender
# 2       709        7.93  Low spender
# 3       764        4.97  Low spender
# 4       764        4.97  Low spender
# 5       777        6.94  Low spender
# 6       825        5.96  Low spender
# 7       910        6.68  Low spender
# 8      1052        7.16  Low spender
# 9      1052        7.16  Low spender
# 10     1379        5.81  Low spender
# 11     1480        5.08  Low spender
# 12     1480        5.08  Low spender
# 13     1480        5.08  Low spender
# 14     1494        6.80  Low spender
# 15     1494        6.80  Low spender
# 16     1494        6.80  Low spender
# 17     1540        6.61  Low spender
# 18     1540        6.61  Low spender
# 19     1540        6.61  Low spender
# 20     1540        6.61  Low spender
# 21     1540        6.61  Low spender
# 22     1540        6.61  Low spender
# 23     1540        6.61  Low spender
# ...

# %%
# counting values
ords_prods_merge['spenders'].value_counts(dropna = False)
# Out:
# spenders
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %% [markdown]
# ## Determine frequent versus non-frequent customers.

# %%
# First Step: Group by user_id, calculate the median value by days_since_prior_order and create a new column 'median_days_since_prior_order'

ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby('user_id')['days_since_prior_order'].transform('median')

# %%
ords_prods_merge['median_days_since_prior_order'].describe()
# Out:
# count   32404854.00
# mean          10.40
# std            7.13
# min            0.00
# 25%            6.00
# 50%            8.00
# 75%           13.00
# max           30.00
# Name: median_days_since_prior_order, dtype: float64

# %%
# Second Step: Creating Flags

# %%
# median of “days_since_prior_order” > 20 == Non-frequent customer

ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
# median of “days_since_prior_order” > 10 and <= 20 == Regular customer

ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order'] > 10) & (ords_prods_merge['median_days_since_prior_order'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
# median of “days_since_prior_order” <= 10 == Frequent customer

ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Checking Output

ords_prods_merge['frequency_flag'].describe()
# Out:
# count              32404854
# unique                    3
# top       Frequent customer
# freq               21559853
# Name: frequency_flag, dtype: object

# %%
# Counting values

ords_prods_merge['frequency_flag'].value_counts(dropna=False)
# Out:
# frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %% [markdown]
# ## Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
# Export changed df 

ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_grouped.pkl'))
